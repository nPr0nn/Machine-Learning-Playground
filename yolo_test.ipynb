# %% [markdown]
# <a href="https://colab.research.google.com/github/nPr0nn/Machine-Learning-Playground/blob/main/yolo_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.0/605.0 kB 4.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
model = YOLO("yolov8n-seg.pt")
# Out:
# ...
# 100%|██████████| 6.73M/6.73M [00:00<00:00, 82.2MB/s]

# %%
results = model.predict("cat_dog.jpg")
# Out:
# image 1/1 /content/cat_dog.jpg: 448x640 1 cat, 1 dog, 12.0ms
# Speed: 6.1ms preprocess, 12.0ms inference, 3.1ms postprocess per image at shape (1, 3, 448, 640)

# %%
def display(display_list):
  plt.figure(figsize=(15, 15))
  title = ['Input Image', 'True Mask', 'Predicted Mask']
  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(display_list[i])
    plt.axis('off')
  plt.show()

# %%
img  = cv2.imread("cat_dog.jpg")
mask_torch = results[0].masks[0].data[0]
mask = mask_torch.cpu().numpy()

# %%
display([img, mask])
